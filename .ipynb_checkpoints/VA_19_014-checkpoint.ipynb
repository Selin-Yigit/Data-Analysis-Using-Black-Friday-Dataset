# %% [markdown]
# # Veri Analizi Final Ödevi
#
# ### Black Friday Sale Veri Seti Kullanılarak Veri Analizi
#
# 19010011014
# Selin YİĞİT

# %% [markdown]
# # Araştırma sorularına ve sonuçlarına genel bakış:

# %% [markdown]
#    1. En çok tercih edilen ürün nedir?
#
#       Cevap: %21.8 oran ileP00025442 ID'sine sahip ürün en çok tercih edilen üründür.
#       <br>
#    2. En çok ürün alan müşteri yaş aralığı nedir?
#
#       Cevap: %42.7 oran ile 26-35 yaş aralığı en çok ürün alımı yapan yaş aralığıdır.
#       <br>
#    3. En az ürünü alan müşteri cinsiyeti nedir?
#
#       Cevap: %23.3 oran ile Female yani kadın cinsiyetine sahip müşteriler en az ürün alımına sahiptir.
#       <br>
#    4. Eksik Veri içeren kaç sütun vardır ve bu sütunların isimleri nelerdir?
#
#       Cevap: 2 taen sütun eksik veri içermektedir. Bu sütunlar Product_Category_2 ve Product_Category_3 adlı sütunlardır.
#       <br>

# %% [markdown]
# # Motivasyon ve arka plan :

# %% [markdown]
# Bu araştırmada "ABC Private Limited" adlı şirketin verileri analiz edilerek farklı kategorideki ürürünler için müşteri satın alma eğilimlerinin araştırılması amaçlandı. Yaş, cinsiyet, medeni hal gibi farklı kategorilerin ürün kategorileri ve satın alama üzerindeki etkileri araştırılarak ilgili şirketin ürün özelleştirme ve satış miktarını arttırma gibi önemli konularda bu analizleri kullanabilmesi amaçlandı. Ayrıca, veriler içinde bulunan eksik verilerin makine öğrenmesi modelleri kullanılarak tahmin edilmesi ile birlikte bu analizlerin bilinmeyen etkenler içinde etkin olması amaçlandı.

# %% [markdown]
# # Veri kümesi ile ilgili bilgiler: Black Friday Sales

# %% [markdown]
# "ABC Private Limited" adlı parekende şirketi, farklı kategorilerdeki çeşitli ürünlere karşı müşteri satın alma davranışını anlamak için seçilen yüksek hacimli ürünler göz önüne alınarak çeşitli müşterilerin satın alma özetlerini paylaşmıştır.
#
# Black Friday Sales veri seti 550068 satır ve 12 sütundan oluşmaktadır. Bu sütunlar sırası ile:
#
# 1. User_ID,
# 2. Product_ID,
# 3. Gender,
# 4. Age,
# 5. Occupation,
# 6. City_Category,
# 7. Stay_In_Current_City_Years,
# 8. Marital_Status,
# 9. Product_Category_1,
# 10. Product_Category_2,
# 11. Product_Category_3,
# 12. Purchase
#
# 3, 4, 5, 6, 7, 8, 9, 10 ve 11 no'lu sütunlar kategorik verilerden oluşmaktadır.
#
# https://www.kaggle.com/datasets/rajeshrampure/black-friday-sale?resource=download

# %% [markdown]
# # Metodoloji:

# %% [markdown]
# ## Veri Hakkında Bilgi Edinme:
#
#    1. Tek Değişkenli Analiz: Her kategorinin kendi içinde analiz edilmesini içerir.
#    2. HeatMap kullanılarak eksik verilerin analiz edilmesi
#    3. İki Değişkenli Analiz: Her Kategorinin 'Purchase' sütununa göre analiz edilmesini içerir.
#    4. Kategorilerin "Product_Category_1" sütunu ile ilişkilerinin analiz edilmesi.
#
#
# ## Feature Engineering:
#
#    1. Label Encoding (Gender ve Age)
#    2. One Hot Encoding (City_Category)
#    3. train_test_split
#    4. StandardScaler
#    5. Ölçeklendirme öncesi ve sonrası verinin analiz edilmesini içerir.
#    6. korelasyon hesabı yapıldı ve korelasyon matrisi oluşturuldu.
#
#
# ## Model Oluşturma:
#
#    1. Linear Regression
#    2. Descision Tree Regression
#    3. Random Forest Regression
#    4. Knn Regression
#    5. Gradient Boost Regression
#
# ## Model Değerlendirme Metrikleri:
#
#    1. R2 Score
#    2. Mean Squared Error (MSE)

# %% [markdown]
# # Sonuçlar:
#
# Modelleme için kullanılan modellerden "ölçeklendirilmiş veriler" ve "ölçeklendirilmemiş veriler" üzerinde en etkilisinin %79.55 oran ile Descision tree regression Modeli olduğu görülürken, "test verileri" üzerinde en etkili modelin %64.88 oran ile Gradient boost regression Modeli olduğu gözlemlenmiştir.
#
# <br>
# Ayrıca bu modeller incelendiğinde Descision Tree Regression, Random Forest Regression ve Gradient Boost Regression gibi modellerde ölçeklendirme yapılıp yapılmamasının öneminin olmadığı gözlemlendi. Çünkü bu algoritmalarda "ölçeklendirilmiş veriler" kullanılarak oluşturulmuş modellerin sonuçları ile "ölçeklendirilmemiş veriler" kullanılarak oluşturulmuş modellerin sonuçları birbirine eşittir. Fakat Lineer Regression ve Knn Regression modelleri incelendiğinde "ölçeklendirilmiş veriler" kullanılarak oluşturulmuş modellerin sonuçları ile "ölçeklendirilmemiş veriler" kullanılarak oluşturulmuş modellerin sonuçlarının farklılık gösterdiği gözlemlenmiştir.

# %% [markdown]
# # Veri Analizi: KOD

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib.ticker import EngFormatter
import math
import warnings
warnings.filterwarnings('ignore')
pd.set_option('display.max_columns',100)

# %%
# Veri Setinin Alınması

bfs_data = pd.read_csv("C:/Users/Selin/Desktop/Ders Dokumanlari/4.Sınıf Dersleri/Bahar Dönemi/Veri Analizi/VA_19_014/VA_19_014.csv")

# %% [markdown]
# ## Veri Hakkında Bilgi Edinme Ve Görselleştirme

# %%
# Veri Setinin Satır-Sütun Bilgisi
bfs_data.shape
# Out:
# (550068, 12)

# %%
# Veri Setinin İlk 5 Satır:
bfs_data.head()
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
# 2  1000001  P00087842      F  0-17          10             A
# 3  1000001  P00085442      F  0-17          10             A
# 4  1000002  P00285442      M   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               0                   3
# 1                          2               0                   1
# 2                          2               0                  12
# 3                          2               0                  12
# 4                         4+               0                   8
#
#    Product_Category_2  Product_Category_3  Purchase
# 0                 NaN                 NaN      8370
# 1                 6.0                14.0     15200
# 2                 NaN                 NaN      1422
# 3                14.0                 NaN      1057
# 4                 NaN                 NaN      7969

# %%
# Veri İle ilgili bilgilerin alınması
bfs_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 550068 entries, 0 to 550067
# Data columns (total 12 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   User_ID                     550068 non-null  int64
#  1   Product_ID                  550068 non-null  object
#  2   Gender                      550068 non-null  object
#  3   Age                         550068 non-null  object
#  4   Occupation                  550068 non-null  int64
#  5   City_Category               550068 non-null  object
#  6   Stay_In_Current_City_Years  550068 non-null  object
#  7   Marital_Status              550068 non-null  int64
#  8   Product_Category_1          550068 non-null  int64
#  9   Product_Category_2          376430 non-null  float64
#  10  Product_Category_3          166821 non-null  float64
#  11  Purchase                    550068 non-null  int64
# dtypes: float64(2), int64(5), object(5)
# memory usage: 50.4+ MB

# %%
# Veri türü Object olan sütunlar formatlandı.
frmt_obj = EngFormatter()

# %%
bfs_data.describe()
# Out:
#             User_ID     Occupation  Marital_Status  Product_Category_1  \
# count  5.500680e+05  550068.000000   550068.000000       550068.000000
# mean   1.003029e+06       8.076707        0.409653            5.404270
# std    1.727592e+03       6.522660        0.491770            3.936211
# min    1.000001e+06       0.000000        0.000000            1.000000
# 25%    1.001516e+06       2.000000        0.000000            1.000000
# 50%    1.003077e+06       7.000000        0.000000            5.000000
# 75%    1.004478e+06      14.000000        1.000000            8.000000
# max    1.006040e+06      20.000000        1.000000           20.000000
#
#        Product_Category_2  Product_Category_3       Purchase
# count       376430.000000       166821.000000  550068.000000
# mean             9.842329           12.668243    9263.968713
# std              5.086590            4.125338    5023.065394
# min              2.000000            3.000000      12.000000
# 25%              5.000000            9.000000    5823.000000
# 50%              9.000000           14.000000    8047.000000
# 75%             15.000000           16.000000   12054.000000
# max             18.000000           18.000000   23961.000000

# %%
# Kategorik sütunların belirlenmesi
categorical_columns = ['Gender','Age','Occupation','City_Category','Stay_In_Current_City_Years','Marital_Status','Product_Category_1','Product_Category_2','Product_Category_3']

# %%
# Kategorik sütunların görselleştirilmesi(Tek Değişkenli Analiz)
for categorical in categorical_columns:
    fig, ax = plt.subplots(figsize = (15,8))
    sns.countplot(data=bfs_data, x=categorical, ax=ax).set(title=f"{categorical} Column")
    ax.yaxis.set_major_formatter(frmt_obj)

# %%
# Veri setindeki eksik verilerin görselleştirilmesi - Product_Category_2 VE Product_Category_3
sns.heatmap(bfs_data.isnull(), yticklabels = False, cbar = True)
# Out:
# <AxesSubplot:>

# %%
# Sütunlardaki toplam eksik veri sayısı
bfs_data.isnull().sum().reset_index()
# Out:
#                          index       0
# 0                      User_ID       0
# 1                   Product_ID       0
# 2                       Gender       0
# 3                          Age       0
# 4                   Occupation       0
# 5                City_Category       0
# 6   Stay_In_Current_City_Years       0
# 7               Marital_Status       0
# 8           Product_Category_1       0
# 9           Product_Category_2  173638
# 10          Product_Category_3  383247
# 11                    Purchase       0

# %%
# Kategorik sütunların görselleştirilmesi(İki Değişkenli Analiz)
# Burada her kategori için Purchase değerleri gözlemlendi.

for categorical in categorical_columns:
    fig, ax = plt.subplots(figsize = (15,8))
    temp = bfs_data.groupby(categorical).agg({'Purchase':sum}).reset_index()
    sns.barplot(data = temp, x=categorical, y = 'Purchase', ax=ax).set(title = f"{categorical} And Purchase")
    ax.yaxis.set_major_formatter(frmt_obj)

# %%
# Kategorilerin "Product_Category_1" sütunu ile ilişkileri gözlemlendi. 
# Bu sayede diğer kategorilerin ürün kategorileri üzerindeki etkisi hakkında fikir edinildi.

for categorical in categorical_columns:
    fig, ax = plt.subplots(figsize =(17,10))
    sns.countplot(data = bfs_data, x= categorical, hue='Product_Category_1')
    ax.yaxis.set_major_formatter(frmt_obj)
    
# Grafikler göz önünde bulundurulursa kategorilerde en çok satılan ürün kategorilerinin 1, 5 ve 8 olduğu gözlemlendi.

# %%
#Burada en çok satılan 5 ürün gözlemlendi.
top_prod=bfs_data[['Product_ID','Purchase']].groupby('Product_ID').sum()
top_prod=top_prod.sort_values(by='Purchase',ascending=False)
top_prod=top_prod.head(5)
top_prod.plot(kind='pie',title='Top 5 products by Purchases',subplots=True,autopct='%1.1f%%',legend=False,ylabel='',figsize=(12,7))
# Out:
# array([<AxesSubplot:>], dtype=object)

# %%
#Burada yaşa göre ürün alınımı gözlemlendi.
top_prod=bfs_data[['Age','Purchase']].groupby('Age').sum()
top_prod=top_prod.sort_values(by='Purchase',ascending=False)
top_prod=top_prod.head(5)
top_prod.plot(kind='pie',title='Age by Purchases',subplots=True,autopct='%1.1f%%',legend=False,ylabel='',figsize=(12,7))
# Out:
# array([<AxesSubplot:>], dtype=object)

# %%
#Burada cinsiyete göre ürün alınımı gözlemlendi.
top_prod=bfs_data[['Gender','Purchase']].groupby('Gender').sum()
top_prod=top_prod.sort_values(by='Purchase',ascending=False)
top_prod=top_prod.head(5)
top_prod.plot(kind='pie',title='Gender by Purchases',subplots=True,autopct='%1.1f%%',legend=False,ylabel='',figsize=(12,7))
# Out:
# array([<AxesSubplot:>], dtype=object)

# %% [markdown]
# ## Feature Engineering

# %%
import sklearn.preprocessing as sk_preprocess
from sklearn.preprocessing import StandardScaler

# %%
#Veri Seti:
bfs_data
# Out:
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 0       1000001  P00069042      F   0-17          10             A
# 1       1000001  P00248942      F   0-17          10             A
# 2       1000001  P00087842      F   0-17          10             A
# 3       1000001  P00085442      F   0-17          10             A
# 4       1000002  P00285442      M    55+          16             C
# ...         ...        ...    ...    ...         ...           ...
# 550063  1006033  P00372445      M  51-55          13             B
# 550064  1006035  P00375436      F  26-35           1             C
# 550065  1006036  P00375436      F  26-35          15             B
# 550066  1006038  P00375436      F    55+           1             C
# 550067  1006039  P00371644      F  46-50           0             B
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                               2               0                   3
# 1                               2               0                   1
# 2                               2               0                  12
# 3                               2               0                  12
# 4                              4+               0                   8
# ...                           ...             ...                 ...
# 550063                          1               1                  20
# 550064                          3               0                  20
# 550065                         4+               1                  20
# 550066                          2               0                  20
# 550067                         4+               1                  20
#
#         Product_Category_2  Product_Category_3  Purchase
# 0                      NaN                 NaN      8370
# 1                      6.0                14.0     15200
# 2                      NaN                 NaN      1422
# 3                     14.0                 NaN      1057
# 4                      NaN                 NaN      7969
# ...                    ...                 ...       ...
# 550063                 NaN                 NaN       368
# 550064                 NaN                 NaN       371
# 550065                 NaN                 NaN       137
# 550066                 NaN                 NaN       365
# 550067                 NaN                 NaN       490
#
# [550068 rows x 12 columns]

# %%
# User_ID ve Product_ID kullanılmayacağından bu sütunlar kaldırıldı.

bfs_data.drop(columns = ['User_ID','Product_ID'], inplace=True)

# %%
bfs_data
# Out:
#        Gender    Age  Occupation City_Category Stay_In_Current_City_Years  \
# 0           F   0-17          10             A                          2
# 1           F   0-17          10             A                          2
# 2           F   0-17          10             A                          2
# 3           F   0-17          10             A                          2
# 4           M    55+          16             C                         4+
# ...       ...    ...         ...           ...                        ...
# 550063      M  51-55          13             B                          1
# 550064      F  26-35           1             C                          3
# 550065      F  26-35          15             B                         4+
# 550066      F    55+           1             C                          2
# 550067      F  46-50           0             B                         4+
#
#         Marital_Status  Product_Category_1  Product_Category_2  \
# 0                    0                   3                 NaN
# 1                    0                   1                 6.0
# 2                    0                  12                 NaN
# 3                    0                  12                14.0
# 4                    0                   8                 NaN
# ...                ...                 ...                 ...
# 550063               1                  20                 NaN
# 550064               0                  20                 NaN
# 550065               1                  20                 NaN
# 550066               0                  20                 NaN
# 550067               1                  20                 NaN
#
#         Product_Category_3  Purchase
# 0                      NaN      8370
# 1                     14.0     15200
# 2                      NaN      1422
# 3                      NaN      1057
# 4                      NaN      7969
# ...                    ...       ...
# 550063                 NaN       368
# 550064                 NaN       371
# 550065                 NaN       137
# 550066                 NaN       365
# 550067                 NaN       490
#
# [550068 rows x 10 columns]

# %%
# Veri setindeki tahmin edilecek sütun veri setinden kaldırıldı.
y_data = bfs_data['Purchase']
bfs_data.drop(columns = ['Purchase'],inplace=True)

# %%
class feature_engineering:
    
    def __init__(self,training_data = bfs_data):
        self.prod_cat2_mode = bfs_data['Product_Category_2'].mode().item()
        self.prod_cat3_mode = bfs_data['Product_Category_3'].mode().item()
        self.std_scaler = sk_preprocess.StandardScaler()
    
    # Encoding İşlemi:
    def do_encoding(self,df): 
        
        # Gender - female ve Male değişkenlerine nümerik değerler atadık.
        df['Gender'] = df['Gender'].map({'F':0,'M':1})

        # Age - yaş aralıkları string olarak verildiğinden bu aralıklara nümerik değerler atadık.
        df['Age'] = df['Age'].map({'0-17':1,'18-25':2,'26-35':3,'36-45':4,'46-50':5,'51-55':6,'55+':7})

        # City_Category - bu kategori değişkenini dummy değişken olarak belirledik.
        city_cats = pd.get_dummies(df['City_Category'],drop_first = True)
        df = pd.concat([df,city_cats],axis=1)
        df.drop(columns = ['City_Category'] , inplace=True)
        

        # Stay_In_Current_City_Years - unique değerleri bularak bu değişkeni düzenledik.
        df['Stay_In_Current_City_Years'].unique()
        df['Stay_In_Current_City_Years'] = df['Stay_In_Current_City_Years'].replace('4+','4').astype(int)

        return df
    
    # Eksik Veri Çözümleme - eksik verilein yerine mod değerlerini atadık. 
    def fillna_with_mode(self,df): 
        df['Product_Category_2'] = df['Product_Category_2'].fillna(self.prod_cat2_mode)
        df['Product_Category_3'] = df['Product_Category_3'].fillna(self.prod_cat3_mode)
        
        return df
    
    # MAIN_FUNCTION
    def do_all(self,df):
        df = self.do_encoding(df = df.copy())
        df = self.fillna_with_mode(df = df.copy())
        return df

# %%
#Class'a ulaşıldı.
feat_eng = feature_engineering(training_data = bfs_data.copy())

# %%
# Veri Setinde özellik seçimi gerçekleştirildi.
bfs_clean = feat_eng.do_all(df = bfs_data.copy())

# %%
# Veri seti %70 eğitim ve %30 test olacak şekilde bölündü.
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(bfs_clean,y_data,test_size = 0.3,random_state = 0)

# %%
x_train
# Out:
#         Gender  Age  Occupation  Stay_In_Current_City_Years  Marital_Status  \
# 532017       1    3           4                           2               1
# 153907       1    3           0                           4               0
# 162868       1    6           1                           2               1
# 75278        1    4          15                           3               0
# 525591       1    3           1                           1               0
# ...        ...  ...         ...                         ...             ...
# 359783       1    3           7                           4               0
# 152315       1    5           7                           1               1
# 117952       0    5          15                           1               1
# 435829       1    2           4                           0               1
# 305711       1    7          17                           0               0
#
#         Product_Category_1  Product_Category_2  Product_Category_3  B  C
# 532017                   1                15.0                16.0  0  0
# 153907                   1                 8.0                17.0  0  0
# 162868                   5                15.0                16.0  1  0
# 75278                    8                14.0                16.0  0  1
# 525591                   5                14.0                16.0  1  0
# ...                    ...                 ...                 ... .. ..
# 359783                   6                10.0                13.0  1  0
# 152315                   8                 8.0                16.0  0  1
# 117952                   5                 8.0                16.0  0  1
# 435829                   2                 4.0                16.0  0  0
# 305711                   8                17.0                16.0  0  1
#
# [385047 rows x 10 columns]

# %%
x_test.head()
# Out:
#         Gender  Age  Occupation  Stay_In_Current_City_Years  Marital_Status  \
# 41001        1    2           0                           3               0
# 16151        1    6           1                           0               0
# 507262       1    3          11                           2               0
# 368698       1    3           7                           4               1
# 353782       1    3           2                           1               1
#
#         Product_Category_1  Product_Category_2  Product_Category_3  B  C
# 41001                    1                 6.0                16.0  0  1
# 16151                   12                 8.0                16.0  0  0
# 507262                   6                 8.0                15.0  0  1
# 368698                   1                 2.0                 9.0  0  1
# 353782                   5                14.0                16.0  0  0

# %%
# Burada ölçeklendirme işlemini gerçekleştirdik. Hem eğitim hemde test veri seti ölçeklendirildi.
# burada train değişkeninin kullanılma sebebi eğitim setinde ölçeklendirme işleminde fitting yapılması gerekirken 
# test veri setinde bu işlemin yapılmamasının gerekmesidir. Bu değişkenle gelen veri setinin hangisi olduğu kontrol edildi.

std_scaler=StandardScaler()
def scaling(df,train):
    cols = df.columns
    if train==True:
        print('Fitting train for scaling')
        df_scaled = std_scaler.fit_transform(df)
    else:
        df_scaled  = std_scaler.transform(df)
        
    df_scaled  = pd.DataFrame(df_scaled,columns = cols)     
    return df_scaled

# %%
# Ölçeklendirme işlemi gerçekleştirildi.
scaled_x_train = scaling(df = x_train.copy(),train = True)
scaled_x_test = scaling(df = x_test.copy(),train = False)
# Out:
# Fitting train for scaling

# %%
# Ölçeklendirme yapılmış ve ölçeklendirme yapılmamış sütunları karşılaştırdık.

def before_vs_after_scaling(df,df_scaled):
    df_scaled.columns = df.columns
    print(df.columns)
    no_of_columns = df.shape[1]
    fig,ax = plt.subplots(no_of_columns,2,figsize = (30,60))
    col_list = df.columns
    
    for col, col_name in zip(range(no_of_columns),col_list):
        sns.histplot(data = df[col_name],kde = True, ax= ax[col,0])
        ax[col,0].set_title(f"Non scaled {col_name} distribution")
        
        sns.histplot(data = df[col_name],kde = True, ax= ax[col,1])
        ax[col,1].set_title(f"Scaled {col_name} distribution")

# %%
before_vs_after_scaling(df = x_train, df_scaled = scaled_x_train)
# Out:
# Index(['Gender', 'Age', 'Occupation', 'Stay_In_Current_City_Years',
#        'Marital_Status', 'Product_Category_1', 'Product_Category_2',
#        'Product_Category_3', 'B', 'C'],
#       dtype='object')

# %%
# Sütunların koelasyonlarını hesapladık.
scaled_x_train.corr()
# Out:
#                               Gender       Age  Occupation  \
# Gender                      1.000000 -0.004631    0.118177
# Age                        -0.004631  1.000000    0.091292
# Occupation                  0.118177  0.091292    1.000000
# Stay_In_Current_City_Years  0.013896 -0.004919    0.030063
# Marital_Status             -0.011521  0.312232    0.024567
# Product_Category_1         -0.046193  0.060697   -0.008948
# Product_Category_2         -0.012935  0.041718    0.001391
# Product_Category_3         -0.007182  0.035881   -0.000060
# B                          -0.005739 -0.018247   -0.011529
# C                          -0.000339  0.110892    0.034257
#
#                             Stay_In_Current_City_Years  Marital_Status  \
# Gender                                        0.013896       -0.011521
# Age                                          -0.004919        0.312232
# Occupation                                    0.030063        0.024567
# Stay_In_Current_City_Years                    1.000000       -0.013426
# Marital_Status                               -0.013426        1.000000
# Product_Category_1                           -0.004285        0.017811
# Product_Category_2                           -0.001068        0.010654
# Product_Category_3                           -0.000638        0.012848
# B                                             0.011102       -0.000730
# C                                             0.010777        0.032291
#
#                             Product_Category_1  Product_Category_2  \
# Gender                               -0.046193           -0.012935
# Age                                   0.060697            0.041718
# Occupation                           -0.008948            0.001391
# Stay_In_Current_City_Years           -0.004285           -0.001068
# Marital_Status                        0.017811            0.010654
# Product_Category_1                    1.000000            0.278782
# Product_Category_2                    0.278782            1.000000
# Product_Category_3                    0.318167            0.463782
# B                                    -0.006115           -0.003817
# C                                    -0.008746           -0.000630
#
#                             Product_Category_3         B         C
# Gender                               -0.007182 -0.005739 -0.000339
# Age                                   0.035881 -0.018247  0.110892
# Occupation                           -0.000060 -0.011529  0.034257
# Stay_In_Current_City_Years           -0.000638  0.011102  0.010777
# Marital_Status                        0.012848 -0.000730  0.032291
# Product_Category_1                    0.318167 -0.006115 -0.008746
# Product_Category_2                    0.463782 -0.003817 -0.000630
# Product_Category_3                    1.000000  0.004169 -0.021719
# B                                     0.004169  1.000000 -0.572443
# C                                    -0.021719 -0.572443  1.000000

# %%
# Korelasyon matrisini bulduk.
correlation_matrix = pd.concat([scaled_x_train,y_train],axis=1).corr()

# %%
correlation_matrix
# Out:
#                               Gender       Age  Occupation  \
# Gender                      1.000000 -0.004631    0.118177
# Age                        -0.004631  1.000000    0.091292
# Occupation                  0.118177  0.091292    1.000000
# Stay_In_Current_City_Years  0.013896 -0.004919    0.030063
# Marital_Status             -0.011521  0.312232    0.024567
# Product_Category_1         -0.046193  0.060697   -0.008948
# Product_Category_2         -0.012935  0.041718    0.001391
# Product_Category_3         -0.007182  0.035881   -0.000060
# B                          -0.005739 -0.018247   -0.011529
# C                          -0.000339  0.110892    0.034257
# Purchase                   -0.002210 -0.000886   -0.001686
#
#                             Stay_In_Current_City_Years  Marital_Status  \
# Gender                                        0.013896       -0.011521
# Age                                          -0.004919        0.312232
# Occupation                                    0.030063        0.024567
# Stay_In_Current_City_Years                    1.000000       -0.013426
# Marital_Status                               -0.013426        1.000000
# Product_Category_1                           -0.004285        0.017811
# Product_Category_2                           -0.001068        0.010654
# Product_Category_3                           -0.000638        0.012848
# B                                             0.011102       -0.000730
# C                                             0.010777        0.032291
# Purchase                                      0.000072       -0.002820
#
#                             Product_Category_1  Product_Category_2  \
# Gender                               -0.046193           -0.012935
# Age                                   0.060697            0.041718
# Occupation                           -0.008948            0.001391
# Stay_In_Current_City_Years           -0.004285           -0.001068
# Marital_Status                        0.017811            0.010654
# Product_Category_1                    1.000000            0.278782
# Product_Category_2                    0.278782            1.000000
# Product_Category_3                    0.318167            0.463782
# B                                    -0.006115           -0.003817
# C                                    -0.008746           -0.000630
# Purchase                              0.000617           -0.004145
#
#                             Product_Category_3         B         C  Purchase
# Gender                               -0.007182 -0.005739 -0.000339 -0.002210
# Age                                   0.035881 -0.018247  0.110892 -0.000886
# Occupation                           -0.000060 -0.011529  0.034257 -0.001686
# Stay_In_Current_City_Years           -0.000638  0.011102  0.010777  0.000072
# Marital_Status                        0.012848 -0.000730  0.032291 -0.002820
# Product_Category_1                    0.318167 -0.006115 -0.008746  0.000617
# Product_Category_2                    0.463782 -0.003817 -0.000630 -0.004145
# Product_Category_3                    1.000000  0.004169 -0.021719 -0.002125
# B                                     0.004169  1.000000 -0.572443 -0.000729
# C                                    -0.021719 -0.572443  1.000000  0.000258
# Purchase                             -0.002125 -0.000729  0.000258  1.000000

# %%
# Korelasyon Matrisini görselleştirdik.
fig,ax = plt.subplots(figsize=(15,10))
sns.heatmap(data = correlation_matrix,annot = True,cmap='hsv')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Model Oluşturma

# %% [markdown]
# Kullanılan Modeller:
# <br>
#   1. Linear Regression
#   2. Descision Tree Regression
#   3. Random Forest Regression
#   4. Knn Regression
#   5. Gradient Boost Regression
#
# <br>
# !! Modellere sırası ile ölçeklendirilmiş veriseti, ölçeklendirilmemiş verri seti ve test veri seti verilmiştir.

# %%
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.ensemble import GradientBoostingRegressor, RandomForestRegressor

from sklearn.metrics import mean_squared_error,r2_score

# %%
# Linear Regression Modeli

LR_model = LinearRegression()

# Ölçeklendirilmiş veriler ile modelleme
LR_model_scaled = LR_model.fit(scaled_x_train.copy(),y_train.copy())
LR_predict_scaled = LR_model.predict(scaled_x_train.copy())
LR_r2score_scaled = r2_score(y_train.copy(), LR_predict_scaled)
LR_mse_scaled = mean_squared_error(y_train.copy(), LR_predict_scaled)

# Ölçeklendirilmemiş veriler ile modelleme
LR_model_non_scaled = LR_model.fit(x_train.copy(),y_train.copy())
LR_predict_non_scaled = LR_model.predict(x_train.copy())
LR_r2score_non_scaled = r2_score(y_train.copy(), LR_predict_non_scaled)
LR_mse_non_scaled = mean_squared_error(y_train.copy(), LR_predict_non_scaled)

# Test verileri ile modelleme
LR_model_test = LR_model.fit(scaled_x_train.copy(),y_train.copy())
LR_predict_test = LR_model.predict(scaled_x_test.copy())
LR_r2score_test = r2_score(y_test.copy(), LR_predict_test)
LR_mse_test = mean_squared_error(y_test.copy(), LR_predict_test)

# Tahminleri görmek için:
predict_data = np.array([[LR_predict_scaled], [LR_predict_non_scaled], [LR_predict_test]])
predict_row_name = ['Scaled Data', 'Non Scaled Data', 'Test Data']
predict_column_name = ['Predict']
predict_dataset = pd.DataFrame(data=predict_data,index = predict_row_name ,columns=predict_column_name)
print(predict_dataset)

print('\n')

# Sonuçları görmek için:
data = np.array([[LR_r2score_scaled,LR_mse_scaled], [LR_r2score_non_scaled,LR_mse_non_scaled], [LR_r2score_test,LR_mse_test]])
row_name = ['Scaled Data', 'Non Scaled Data', 'Test Data']
column_name = ['R2 Score','MSE']
dataset = pd.DataFrame(data=data,index = row_name ,columns=column_name)
print(dataset)
# Out:
#                                                            Predict
# Scaled Data      [10596.217697148124, 10509.955654822259, 9496....
# Non Scaled Data  [10596.217697148117, 10509.955654822252, 9496....
# Test Data        [11204.202921015933, 6541.631949296175, 9520.4...
#
#
#                  R2 Score           MSE
# Scaled Data      0.131665  2.188572e+07
# Non Scaled Data  0.131665  2.188572e+07
# Test Data        0.130259  2.199910e+07

# %%
# Descision tree regression Modeli

DTR_model = DecisionTreeRegressor()

# Ölçeklendirilmiş veriler ile modelleme
DTR_model_scaled = DTR_model.fit(scaled_x_train.copy(),y_train.copy())
DTR_predict_scaled = DTR_model.predict(scaled_x_train.copy())
DTR_r2score_scaled = r2_score(y_train.copy(), DTR_predict_scaled)
DTR_mse_scaled = mean_squared_error(y_train.copy(), DTR_predict_scaled)

# Ölçeklendirilmemiş veriler ile modelleme
DTR_model_non_scaled = DTR_model.fit(x_train.copy(),y_train.copy())
DTR_predict_non_scaled = DTR_model.predict(x_train.copy())
DTR_r2score_non_scaled = r2_score(y_train.copy(),DTR_predict_non_scaled)
DTR_mse_non_scaled = mean_squared_error(y_train.copy(), DTR_predict_non_scaled)

# Test verileri ile modelleme
DTR_model_test = DTR_model.fit(scaled_x_train.copy(),y_train.copy())
DTR_predict_test = DTR_model.predict(scaled_x_test.copy())
DTR_r2score_test = r2_score(y_test.copy(), DTR_predict_test)
DTR_mse_test = mean_squared_error(y_test.copy(), DTR_predict_test)


# Tahminleri görmek için:
predict_data = np.array([[DTR_predict_scaled], [DTR_predict_non_scaled], [DTR_predict_test]])
predict_row_name = ['Scaled Data', 'Non Scaled Data', 'Test Data']
predict_column_name = ['Predict']
predict_dataset = pd.DataFrame(data=predict_data,index = predict_row_name ,columns=predict_column_name)
print(predict_dataset)

print('\n')

# Sonuçları görmek için:
data = np.array([[DTR_r2score_scaled,DTR_mse_scaled], [DTR_r2score_non_scaled,DTR_mse_non_scaled], [DTR_r2score_test,DTR_mse_test]])
row_name = ['Scaled Data', 'Non Scaled Data', 'Test Data']
column_name = ['R2 Score','MSE']
dataset = pd.DataFrame(data=data,index = row_name ,columns=column_name)
print(dataset)
# Out:
#                                                            Predict
# Scaled Data      [12334.615384615385, 15751.5, 7058.4, 7480.416...
# Non Scaled Data  [12334.615384615385, 15751.5, 7058.4, 7480.416...
# Test Data        [15688.5, 1387.0, 16181.5, 13095.666666666666,...
#
#
#                  R2 Score           MSE
# Scaled Data      0.795525  5.153639e+06
# Non Scaled Data  0.795525  5.153639e+06
# Test Data        0.566188  1.097279e+07

# %%
# Random Forest regression Modeli

RND_model = RandomForestRegressor()

# Ölçeklendirilmiş veriler ile modelleme
RND_model_scaled = RND_model.fit(scaled_x_train.copy(),y_train.copy())
RND_predict_scaled = RND_model.predict(scaled_x_train.copy())
RND_r2score_scaled = r2_score(y_train.copy(), RND_predict_scaled)
RND_mse_scaled = mean_squared_error(y_train.copy(), RND_predict_scaled)

# Ölçeklendirilmemiş veriler ile modelleme
RND_model_non_scaled = RND_model.fit(x_train.copy(),y_train.copy())
RND_predict_non_scaled = RND_model.predict(x_train.copy())
RND_r2score_non_scaled = r2_score(y_train.copy(),RND_predict_non_scaled)
RND_mse_non_scaled = mean_squared_error(y_train.copy(), RND_predict_non_scaled)

# Test verileri ile modelleme
RND_model_test = RND_model.fit(scaled_x_train.copy(),y_train.copy())
RND_predict_test = RND_model.predict(scaled_x_test.copy())
RND_r2score_test = r2_score(y_test.copy(), RND_predict_test)
RND_mse_test = mean_squared_error(y_test.copy(), RND_predict_test)


# Tahminleri görmek için:
predict_data = np.array([[RND_predict_scaled], [RND_predict_non_scaled], [RND_predict_test]])
predict_row_name = ['Scaled Data', 'Non Scaled Data', 'Test Data']
predict_column_name = ['Predict']
predict_dataset = pd.DataFrame(data=predict_data,index = predict_row_name ,columns=predict_column_name)
print(predict_dataset)

print('\n')

# Sonuçları görmek için:
data = np.array([[RND_r2score_scaled,RND_mse_scaled], [RND_r2score_non_scaled,RND_mse_non_scaled], [RND_r2score_test,RND_mse_test]])
row_name = ['Scaled Data', 'Non Scaled Data', 'Test Data']
column_name = ['R2 Score','MSE']
dataset = pd.DataFrame(data=data,index = row_name ,columns=column_name)
print(dataset)
# Out:
#                                                            Predict
# Scaled Data      [12453.22932446329, 15740.583499999999, 7067.3...
# Non Scaled Data  [12286.3695406943, 15686.315484126986, 7066.65...
# Test Data        [15284.969666666668, 1269.0093333333332, 16553...
#
#
#                  R2 Score           MSE
# Scaled Data      0.784939  5.420434e+06
# Non Scaled Data  0.784966  5.419766e+06
# Test Data        0.634411  9.247152e+06

# %%
# Knn regression Modeli

KNN_model = KNeighborsRegressor()

# Ölçeklendirilmiş veriler ile modelleme
KNN_model_scaled = KNN_model.fit(scaled_x_train.copy(), y_train.copy())
KNN_predict_scaled = KNN_model_scaled.predict(scaled_x_train.copy())
KNN_r2score_scaled = r2_score(y_train.copy(), KNN_predict_scaled)
KNN_mse_scaled = mean_squared_error(y_train.copy(), KNN_predict_scaled)


# Ölçeklendirilmemiş veriler ile modelleme
KNN_model_non_scaled = KNN_model.fit(x_train.copy(), y_train.copy())
KNN_predict_non_scaled = KNN_model_non_scaled.predict(x_train.copy())
KNN_r2score_non_scaled = r2_score(y_train.copy(), KNN_predict_non_scaled)
KNN_mse_non_scaled = mean_squared_error(y_train.copy(), KNN_predict_non_scaled)


# Test verileri ile modelleme
KNN_model_test = KNN_model.fit(scaled_x_train.copy(), y_train.copy())
KNN_predict_test = KNN_model_test.predict(scaled_x_test.copy())
KNN_r2score_test = r2_score(y_test.copy(), KNN_predict_test)
KNN_mse_test = mean_squared_error(y_test.copy(), KNN_predict_test)


# Tahminleri görmek için:
predict_data = np.array([[KNN_predict_scaled], [KNN_predict_non_scaled], [KNN_predict_test]])
predict_row_name = ['Scaled Data', 'Non Scaled Data', 'Test Data']
predict_column_name = ['Predict']
predict_dataset = pd.DataFrame(data=predict_data, index=predict_row_name, columns=predict_column_name)
print(predict_dataset)
print('\n')

# Sonuçları görmek için:
data = np.array([[KNN_r2score_scaled, KNN_mse_scaled], [KNN_r2score_non_scaled, KNN_mse_non_scaled], [KNN_r2score_test, KNN_mse_test]])
row_name = ['Scaled Data', 'Non Scaled Data', 'Test Data']
column_name = ['R2 Score', 'MSE']
dataset = pd.DataFrame(data=data, index=row_name, columns=column_name)
print(dataset)
# Out:
#                                                            Predict
# Scaled Data      [14604.6, 13506.8, 7058.4, 6825.0, 4926.6, 434...
# Non Scaled Data  [14604.6, 13331.0, 7058.4, 6370.6, 4926.6, 669...
# Test Data        [14119.4, 3202.6, 15545.6, 12536.8, 5959.8, 76...
#
#
#                  R2 Score           MSE
# Scaled Data      0.649230  8.840890e+06
# Non Scaled Data  0.689105  7.835871e+06
# Test Data        0.521399  1.210568e+07

# %%
# Gradient boost regression Modeli

GRD_model = GradientBoostingRegressor()

# Ölçeklendirilmiş veriler ile modelleme
GRD_model_scaled = GRD_model.fit(scaled_x_train.copy(),y_train.copy())
GRD_predict_scaled = GRD_model.predict(scaled_x_train.copy())
GRD_r2score_scaled = r2_score(y_train.copy(), GRD_predict_scaled)
GRD_mse_scaled = mean_squared_error(y_train.copy(), GRD_predict_scaled)

# Ölçeklendirilmemiş veriler ile modelleme
GRD_model_non_scaled = GRD_model.fit(x_train.copy(),y_train.copy())
GRD_predict_non_scaled = GRD_model.predict(x_train.copy())
GRD_r2score_non_scaled = r2_score(y_train.copy(),GRD_predict_non_scaled)
GRD_mse_non_scaled = mean_squared_error(y_train.copy(), GRD_predict_non_scaled)

# Test verileri ile modelleme
GRD_model_test = GRD_model.fit(scaled_x_train.copy(),y_train.copy())
GRD_predict_test = GRD_model.predict(scaled_x_test.copy())
GRD_r2score_test = r2_score(y_test.copy(), GRD_predict_test)
GRD_mse_test = mean_squared_error(y_test.copy(), GRD_predict_test)


# Tahminleri görmek için:
predict_data = np.array([[GRD_predict_scaled], [GRD_predict_non_scaled], [GRD_predict_test]])
predict_row_name = ['Scaled Data', 'Non Scaled Data', 'Test Data']
predict_column_name = ['Predict']
predict_dataset = pd.DataFrame(data=predict_data,index = predict_row_name ,columns=predict_column_name)
print(predict_dataset)

print('\n')

# Sonuçları görmek için:
data = np.array([[GRD_r2score_scaled,GRD_mse_scaled], [GRD_r2score_non_scaled,GRD_mse_non_scaled], [GRD_r2score_test,GRD_mse_test]])
row_name = ['Scaled Data', 'Non Scaled Data', 'Test Data']
column_name = ['R2 Score','MSE']
dataset = pd.DataFrame(data=data,index = row_name ,columns=column_name)
print(dataset)
# Out:
#                                                            Predict
# Scaled Data      [13103.641054252817, 14374.094572793558, 6395....
# Non Scaled Data  [13103.641054252861, 14374.094572793589, 6395....
# Test Data        [13626.160839276343, 1414.2090273364415, 15663...
#
#
#                  R2 Score           MSE
# Scaled Data      0.647525  8.883852e+06
# Non Scaled Data  0.647525  8.883852e+06
# Test Data        0.648809  8.882963e+06
